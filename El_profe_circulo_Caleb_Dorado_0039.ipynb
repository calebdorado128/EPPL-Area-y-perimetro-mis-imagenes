# %% [markdown]
# <a href="https://colab.research.google.com/github/calebdorado128/EPPL-Area-y-perimetro-mis-imagenes/blob/main/El_profe_circulo_Caleb_Dorado_0039.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Caleb Dorado, NL = 14, Fecha = 25/Mar/2026 ⚛
# ---
# # Calcular Area y Perimetro de un circulo
# ---
# ![](https://github.com/calebdorado128/EPPL-Area-y-perimetro-mis-imagenes/blob/main/circulo_area_perimetro.PNG?raw=true)
#
# ---
# ## Formula para calcular Area
# $A=\pi*r^2$
# ---
# ## Formula para calcular Perimetro
# $P=2*\pi*r$
# ---
# ## Datos de entrada
# $r$ ?
# ---
# ## Diagrama de flujo en LucidChart
# ![](https://raw.githubusercontent.com/calebdorado128/EPPL-Area-y-perimetro-mis-imagenes/refs/heads/main/DF%20Area%20Perimetro%20circulo.png)

# %%
# Calcular area y perimetro de un circulo
# Variables A, P, r
# Formula A = pi * r^2 y P = 2 * pi * r
# Capturar el valor de r
import math
print("Calcular area y perimetro de un circulo")
r = float(input("Ingrese el valor del radio: "))
A = math.pi * r**2
P = 2 * math.pi * r
print("El area del circulo es: ", A)
print("El perimetro del circulo es: ", P)
print("Caleb Dorado NL = 14")
# Out:
# Calcular area y perimetro de un circulo
# Ingrese el valor del radio: 5
# El area del circulo es:  78.53981633974483
# El perimetro del circulo es:  31.41592653589793
# Caleb Dorado NL = 14

# %% [markdown]
# # Relacion entre codigo y DF en TlDraw
# ![](https://raw.githubusercontent.com/calebdorado128/EPPL-Area-y-perimetro-mis-imagenes/refs/heads/main/TlDraw%20DF%20%20y%20Codigo.png)
